# %% [markdown]
# <a href="https://colab.research.google.com/github/spandana1320/competitive_programming/blob/main/rabinkarp_and_kmp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def rabin_karp(text, pattern):
    d = 256  # number of characters in input alphabet
    q = 101  # prime number for hashing

    n = len(text)
    m = len(pattern)
    p_hash = 0  # hash value for pattern
    t_hash = 0  # hash value for text window
    h = 1

    # The value of h would be "pow(d, m-1) % q"
    for i in range(m - 1):
        h = (h * d) % q

    # Calculate initial hash values
    for i in range(m):
        p_hash = (d * p_hash + ord(pattern[i])) % q
        t_hash = (d * t_hash + ord(text[i])) % q

    # Slide pattern over text
    for i in range(n - m + 1):
        if p_hash == t_hash:
            # Check characters one by one
            if text[i:i+m] == pattern:
                print(f"Pattern found at index {i}")

        # Calculate next window hash
        if i < n - m:
            t_hash = (d * (t_hash - ord(text[i]) * h) + ord(text[i + m])) % q

            if t_hash < 0:
                t_hash += q


# 🔽 Dynamic Input
text = input("Enter text: ")
pattern = input("Enter pattern: ")

rabin_karp(text, pattern)
# Out:
# Enter text: aaaaabbbcccabc
# Enter pattern: abc
# Pattern found at index 11

# %%
def compute_lps(pattern):
    m = len(pattern)
    lps = [0] * m
    length = 0  # length of previous longest prefix suffix
    i = 1

    while i < m:
        if pattern[i] == pattern[length]:
            length += 1
            lps[i] = length
            i += 1
        else:
            if length != 0:
                length = lps[length - 1]
            else:
                lps[i] = 0
                i += 1
    return lps


def kmp_search(text, pattern):
    n = len(text)
    m = len(pattern)

    lps = compute_lps(pattern)

    i = 0  # index for text
    j = 0  # index for pattern

    while i < n:
        if pattern[j] == text[i]:
            i += 1
            j += 1

        if j == m:
            print(f"Pattern found at index {i - j}")
            j = lps[j - 1]

        elif i < n and pattern[j] != text[i]:
            if j != 0:
                j = lps[j - 1]
            else:
                i += 1


# 🔽 Dynamic Input
text = input("Enter text: ")
pattern = input("Enter pattern: ")

kmp_search(text, pattern)
# Out:
# Enter text: abcabc
# Enter pattern: bca
# Pattern found at index 1

# %%
def rabin_karp(text, pattern):
    d = 256   # base (ASCII)
    q = 101   # prime modulus

    n = len(text)
    m = len(pattern)

    p_hash = 0
    t_hash = 0
    h = 1

    # Step 1: Compute h = d^(m-1) % q
    for i in range(m - 1):
        h = (h * d) % q

    # Step 2: Compute initial hash using formula
    for i in range(m):
        p_hash = (d * p_hash + ord(pattern[i])) % q
        t_hash = (d * t_hash + ord(text[i])) % q

    # Step 3: Sliding window
    for i in range(n - m + 1):

        # Check hash match
        if p_hash == t_hash:
            if text[i:i+m] == pattern:
                print(f"Pattern found at index {i}")

        # Step 4: Rolling hash formula
        if i < n - m:
            t_hash = (d * (t_hash - ord(text[i]) * h) + ord(text[i + m])) % q

            # Handle negative hash
            if t_hash < 0:
                t_hash += q


# 🔽 Dynamic Input
text = input("Enter text: ")
pattern = input("Enter pattern: ")

rabin_karp(text, pattern)
# Out:
# Enter text: abcaabc
# Enter pattern: aab
# Pattern found at index 3
