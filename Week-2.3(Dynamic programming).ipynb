# %% [markdown]
# <a href="https://colab.research.google.com/github/spandana1320/competitive_programming/blob/main/Week-2.3(Dynamic%20programming).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Fibonacci using Memoization

def fibonacci(n, memo):
    if n == 0:
        return 0
    if n == 1:
        return 1

    if n in memo:
        return memo[n]

    memo[n] = fibonacci(n - 1, memo) + fibonacci(n - 2, memo)
    return memo[n]

n = int(input())
memo = {}
result = fibonacci(n, memo)
print(result)
# Out:
# 10
# 55
