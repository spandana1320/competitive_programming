# %% [markdown]
# <a href="https://colab.research.google.com/github/spandana1320/competitive_programming/blob/main/Week_3-5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Subset Sum Using Meet-in-the-Middle
from bisect import bisect_left

def subset_sum_meet_in_middle(arr, S):
    n = len(arr)
    mid = n // 2

    # Split into two halves
    left = arr[:mid]
    right = arr[mid:]

    # Generate all subset sums for a given list
    def generate_sums(nums):
        sums = []
        def dfs(i, current_sum):
            if i == len(nums):
                sums.append(current_sum)
                return
            dfs(i + 1, current_sum)           # exclude element
            dfs(i + 1, current_sum + nums[i]) # include element
        dfs(0, 0)
        return sums

    left_sums = generate_sums(left)
    right_sums = generate_sums(right)
    right_sums.sort()

    # Check if any combination gives target S
    for ls in left_sums:
        need = S - ls
        idx = bisect_left(right_sums, need)
        if idx < len(right_sums) and right_sums[idx] == need:
            return True
    return False


# Driver code
T = int(input().strip())
for _ in range(T):
    N, S = map(int, input().split())
    arr = list(map(int, input().split()))
    if subset_sum_meet_in_middle(arr, S):
        print("YES")
    else:
        print("NO")
# Out:
# 2
# 4 9
# 3 1 5 7
# YES
# 5 10
# 2 4 6 8 1
# YES
